# %%
import pandas as pd

# %%
df = pd.read_csv('results.csv', parse_dates=True, encoding='ISO-8859-1')

# %%
df.head()
# Out:
#     Season              DateTime     HomeTeam        AwayTeam  FTHG  FTAG FTR
# 0  1993-94  1993-08-14T00:00:00Z      Arsenal        Coventry     0     3   A  \
# 1  1993-94  1993-08-14T00:00:00Z  Aston Villa             QPR     4     1   H
# 2  1993-94  1993-08-14T00:00:00Z      Chelsea       Blackburn     1     2   A
# 3  1993-94  1993-08-14T00:00:00Z    Liverpool  Sheffield Weds     2     0   H
# 4  1993-94  1993-08-14T00:00:00Z     Man City           Leeds     1     1   D
#
#    HTHG  HTAG  HTR  ... HST  AST  HC  AC  HF  AF  HY  AY  HR  AR
# 0   NaN   NaN  NaN  ... NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 1   NaN   NaN  NaN  ... NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 2   NaN   NaN  NaN  ... NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 3   NaN   NaN  NaN  ... NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 4   NaN   NaN  NaN  ... NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
#
# [5 rows x 23 columns]

# %%
df.tail()
# Out:
#         Season              DateTime     HomeTeam        AwayTeam  FTHG  FTAG
# 11108  2021-22  2022-04-09T17:30:00Z  Aston Villa       Tottenham     0     4  \
# 11109  2021-22  2022-04-10T14:00:00Z    Brentford        West Ham     2     0
# 11110  2021-22  2022-04-10T14:00:00Z    Leicester  Crystal Palace     2     1
# 11111  2021-22  2022-04-10T14:00:00Z      Norwich         Burnley     2     0
# 11112  2021-22  2022-04-10T16:30:00Z     Man City       Liverpool     2     2
#
#       FTR  HTHG  HTAG HTR  ...  HST  AST   HC   AC    HF    AF   HY   AY   HR
# 11108   A   0.0   1.0   A  ...  8.0  5.0  9.0  3.0  12.0  14.0  2.0  3.0  0.0  \
# 11109   H   0.0   0.0   D  ...  7.0  1.0  4.0  6.0   2.0   6.0  0.0  1.0  0.0
# 11110   H   2.0   0.0   H  ...  3.0  3.0  3.0  4.0  11.0  12.0  1.0  1.0  0.0
# 11111   H   1.0   0.0   H  ...  6.0  4.0  6.0  7.0  12.0  10.0  1.0  1.0  0.0
# 11112   D   2.0   1.0   H  ...  5.0  4.0  4.0  1.0   9.0  11.0  1.0  4.0  0.0
#
#         AR
# 11108  0.0
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#         Season              DateTime     HomeTeam        AwayTeam  FTHG  FTAG
# 0      1993-94  1993-08-14T00:00:00Z      Arsenal        Coventry     0     3  \
# 1      1993-94  1993-08-14T00:00:00Z  Aston Villa             QPR     4     1
# 2      1993-94  1993-08-14T00:00:00Z      Chelsea       Blackburn     1     2
# 3      1993-94  1993-08-14T00:00:00Z    Liverpool  Sheffield Weds     2     0
# 4      1993-94  1993-08-14T00:00:00Z     Man City           Leeds     1     1
# ...        ...                   ...          ...             ...   ...   ...
# 11108  2021-22  2022-04-09T17:30:00Z  Aston Villa       Tottenham     0     4
# 11109  2021-22  2022-04-10T14:00:00Z    Brentford        West Ham     2     0
# 11110  2021-22  2022-04-10T14:00:00Z    Leicester  Crystal Palace     2     1
# 11111  2021-22  2022-04-10T14:00:00Z      Norwich         Burnley     2     0
# 11112  2021-22  2022-04-10T16:30:00Z     Man City       Liverpool     2     2
#
# ...

# %%
df["HomeTeam"].value_counts()
df["AwayTeam"].value_counts()
# Out:
# AwayTeam
# Tottenham           552
# Chelsea             552
# Liverpool           552
# Everton             551
# Man United          551
# Arsenal             550
# Newcastle           514
# Aston Villa         495
# West Ham            495
# Man City            457
# Southampton         418
# Blackburn           327
# Sunderland          304
# Leicester           301
# Fulham              285
# Middlesbrough       266
# Leeds               248
# Bolton              247
# West Brom           247
# Crystal Palace      226
# Stoke               190
# Norwich             171
# Coventry            156
# Charlton            152
# Wigan               152
# Wolves              149
# Watford             149
# Burnley             148
# Sheffield Weds      137
# Wimbledon           137
# Derby               133
# Swansea             133
# Birmingham          133
# Portsmouth          133
# QPR                 118
# Bournemouth          95
# Hull                 95
# Brighton             91
# ...

# %%
df = df[df['Season'] != "2021-22"]

# %%
team_sum = df["AwayTeam"].value_counts() + df["HomeTeam"].value_counts()

# %%
team_sum.sort_values(ascending=False).tail()
# Out:
# Bradford     76
# Oldham       42
# Swindon      42
# Barnsley     38
# Blackpool    38
# Name: count, dtype: int64

# %%
team_sum.count()
# Out:
# 49

# %%
df.head()
# Out:
#     Season              DateTime     HomeTeam        AwayTeam  FTHG  FTAG FTR
# 0  1993-94  1993-08-14T00:00:00Z      Arsenal        Coventry     0     3   A  \
# 1  1993-94  1993-08-14T00:00:00Z  Aston Villa             QPR     4     1   H
# 2  1993-94  1993-08-14T00:00:00Z      Chelsea       Blackburn     1     2   A
# 3  1993-94  1993-08-14T00:00:00Z    Liverpool  Sheffield Weds     2     0   H
# 4  1993-94  1993-08-14T00:00:00Z     Man City           Leeds     1     1   D
#
#    HTHG  HTAG  HTR Referee  HS  AS  HST  AST  HC  AC  HF  AF  HY  AY  HR  AR
# 0   NaN   NaN  NaN     NaN NaN NaN  NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 1   NaN   NaN  NaN     NaN NaN NaN  NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 2   NaN   NaN  NaN     NaN NaN NaN  NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 3   NaN   NaN  NaN     NaN NaN NaN  NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 4   NaN   NaN  NaN     NaN NaN NaN  NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN

# %%
df.loc[1][2] #rows and columns
# Out:
# 'Aston Villa'

# %%
df.iloc[7500]
# Out:
# Season                   2012-13
# DateTime    2012-11-17T00:00:00Z
# HomeTeam               West Brom
# AwayTeam                 Chelsea
# FTHG                           2
# FTAG                           1
# FTR                            H
# HTHG                         1.0
# HTAG                         1.0
# HTR                            D
# Referee                 M Oliver
# HS                           8.0
# AS                          19.0
# HST                          6.0
# AST                         12.0
# HC                           0.0
# AC                          12.0
# HF                           7.0
# AF                          13.0
# HY                           0.0
# AY                           0.0
# HR                           0.0
# AR                           0.0
# Name: 7500, dtype: object

# %%
df["FTAG"].mean()
# Out:
# 1.1368011847463901

# %%
df["FTHG"].mean()
# Out:
# 1.5191595705294336

# %%
df["FTHG"].sum() + df["FTAG"].sum()
# Out:
# 28695

# %%
df["HomeTeam"].unique()
# Out:
# array(['Arsenal', 'Aston Villa', 'Chelsea', 'Liverpool', 'Man City',
#        'Newcastle', 'Oldham', 'Sheffield United', 'Southampton',
#        'West Ham', 'Norwich', 'Tottenham', 'Everton', 'Ipswich', 'Leeds',
#        'Wimbledon', 'Blackburn', 'Coventry', 'Man United', 'QPR',
#        'Sheffield Weds', 'Swindon', 'Crystal Palace', 'Leicester',
#        "Nott'm Forest", 'Bolton', 'Middlesbrough', 'Derby', 'Sunderland',
#        'Barnsley', 'Charlton', 'Watford', 'Bradford', 'Fulham',
#        'Birmingham', 'West Brom', 'Portsmouth', 'Wolves', 'Wigan',
#        'Reading', 'Hull', 'Stoke', 'Burnley', 'Blackpool', 'Swansea',
#        'Cardiff', 'Bournemouth', 'Brighton', 'Huddersfield'], dtype=object)

# %%
len(df)
# Out:
# 10804

# %%
#Attemp to count the number of wins

# %%
df.iloc[1] #go through every game
# Out:
# Season                   1993-94
# DateTime    1993-08-14T00:00:00Z
# HomeTeam             Aston Villa
# AwayTeam                     QPR
# FTHG                           4
# FTAG                           1
# FTR                            H
# HTHG                         NaN
# HTAG                         NaN
# HTR                          NaN
# Referee                      NaN
# HS                           NaN
# AS                           NaN
# HST                          NaN
# AST                          NaN
# HC                           NaN
# AC                           NaN
# HF                           NaN
# AF                           NaN
# HY                           NaN
# AY                           NaN
# HR                           NaN
# AR                           NaN
# Name: 1, dtype: object

# %%
df.iloc[1][2] #Access the home team
# Out:
# 'Aston Villa'

# %%
df.iloc[1]
# Out:
# Season                   1993-94
# DateTime    1993-08-14T00:00:00Z
# HomeTeam             Aston Villa
# AwayTeam                     QPR
# FTHG                           4
# FTAG                           1
# FTR                            H
# HTHG                         NaN
# HTAG                         NaN
# HTR                          NaN
# Referee                      NaN
# HS                           NaN
# AS                           NaN
# HST                          NaN
# AST                          NaN
# HC                           NaN
# AC                           NaN
# HF                           NaN
# AF                           NaN
# HY                           NaN
# AY                           NaN
# HR                           NaN
# AR                           NaN
# Name: 1, dtype: object

# %%
team_sum
# Out:
# Arsenal             1072
# Aston Villa          958
# Barnsley              38
# Birmingham           266
# Blackburn            654
# Blackpool             38
# Bolton               494
# Bournemouth          190
# Bradford              76
# Brighton             152
# Burnley              266
# Cardiff               76
# Charlton             304
# Chelsea             1072
# Coventry             312
# Crystal Palace       422
# Derby                266
# Everton             1072
# Fulham               570
# Huddersfield          76
# Hull                 190
# Ipswich              160
# Leeds                464
# Leicester            574
# Liverpool           1072
# Man City             882
# Man United          1072
# Middlesbrough        532
# Newcastle            996
# Norwich              312
# Nott'm Forest        156
# Oldham                42
# Portsmouth           266
# QPR                  236
# Reading              114
# Sheffield United     156
# Sheffield Weds       274
# ...

# %%
df.iloc[1]
# Out:
# Season                   1993-94
# DateTime    1993-08-14T00:00:00Z
# HomeTeam             Aston Villa
# AwayTeam                     QPR
# FTHG                           4
# FTAG                           1
# FTR                            H
# HTHG                         NaN
# HTAG                         NaN
# HTR                          NaN
# Referee                      NaN
# HS                           NaN
# AS                           NaN
# HST                          NaN
# AST                          NaN
# HC                           NaN
# AC                           NaN
# HF                           NaN
# AF                           NaN
# HY                           NaN
# AY                           NaN
# HR                           NaN
# AR                           NaN
# Name: 1, dtype: object

# %%
df["Win"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\AlexanderTkachenko\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File c:\Users\AlexanderTkachenko\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\AlexanderTkachenko\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Win'
#
# ...

# %%
team_sum.loc[:, "Win"] = None

# %%
team_sum.loc[:, "Draw"] = None

# %%
team_sum.loc[:, "Loss"] = None

# %%
df
# Out:
#         Season              DateTime          HomeTeam        AwayTeam  FTHG
# 0      1993-94  1993-08-14T00:00:00Z           Arsenal        Coventry     0  \
# 1      1993-94  1993-08-14T00:00:00Z       Aston Villa             QPR     4
# 2      1993-94  1993-08-14T00:00:00Z           Chelsea       Blackburn     1
# 3      1993-94  1993-08-14T00:00:00Z         Liverpool  Sheffield Weds     2
# 4      1993-94  1993-08-14T00:00:00Z          Man City           Leeds     1
# ...        ...                   ...               ...             ...   ...
# 10799  2020-21  2021-05-23T16:00:00Z         Liverpool  Crystal Palace     2
# 10800  2020-21  2021-05-23T16:00:00Z          Man City         Everton     5
# 10801  2020-21  2021-05-23T16:00:00Z  Sheffield United         Burnley     1
# 10802  2020-21  2021-05-23T16:00:00Z          West Ham     Southampton     3
# 10803  2020-21  2021-05-23T16:00:00Z            Wolves      Man United     1
#
# ...
