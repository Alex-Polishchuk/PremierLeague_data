# %%
import pandas as pd

# %%
df = pd.read_csv('results.csv', parse_dates=True, encoding='ISO-8859-1')

# %%
df.head()
# Out:
#     Season              DateTime     HomeTeam        AwayTeam  FTHG  FTAG FTR
# 0  1993-94  1993-08-14T00:00:00Z      Arsenal        Coventry     0     3   A  \
# 1  1993-94  1993-08-14T00:00:00Z  Aston Villa             QPR     4     1   H
# 2  1993-94  1993-08-14T00:00:00Z      Chelsea       Blackburn     1     2   A
# 3  1993-94  1993-08-14T00:00:00Z    Liverpool  Sheffield Weds     2     0   H
# 4  1993-94  1993-08-14T00:00:00Z     Man City           Leeds     1     1   D
#
#    HTHG  HTAG  HTR Referee  HS  AS  HST  AST  HC  AC  HF  AF  HY  AY  HR  AR
# 0   NaN   NaN  NaN     NaN NaN NaN  NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 1   NaN   NaN  NaN     NaN NaN NaN  NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 2   NaN   NaN  NaN     NaN NaN NaN  NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 3   NaN   NaN  NaN     NaN NaN NaN  NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 4   NaN   NaN  NaN     NaN NaN NaN  NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN

# %%
df.tail()
# Out:
#         Season              DateTime     HomeTeam        AwayTeam  FTHG  FTAG
# 11108  2021-22  2022-04-09T17:30:00Z  Aston Villa       Tottenham     0     4  \
# 11109  2021-22  2022-04-10T14:00:00Z    Brentford        West Ham     2     0
# 11110  2021-22  2022-04-10T14:00:00Z    Leicester  Crystal Palace     2     1
# 11111  2021-22  2022-04-10T14:00:00Z      Norwich         Burnley     2     0
# 11112  2021-22  2022-04-10T16:30:00Z     Man City       Liverpool     2     2
#
#       FTR  HTHG  HTAG HTR     Referee    HS    AS  HST  AST   HC   AC    HF
# 11108   A   0.0   1.0   A     G Scott   9.0  11.0  8.0  5.0  9.0  3.0  12.0  \
# 11109   H   0.0   0.0   D  M Atkinson  15.0   5.0  7.0  1.0  4.0  6.0   2.0
# 11110   H   2.0   0.0   H     R Jones  12.0  11.0  3.0  3.0  3.0  4.0  11.0
# 11111   H   1.0   0.0   H    M Oliver  17.0  18.0  6.0  4.0  6.0  7.0  12.0
# 11112   D   2.0   1.0   H    A Taylor  11.0   6.0  5.0  4.0  4.0  1.0   9.0
#
#          AF   HY   AY   HR   AR
# 11108  14.0  2.0  3.0  0.0  0.0
# 11109   6.0  0.0  1.0  0.0  0.0
# 11110  12.0  1.0  1.0  0.0  0.0
# 11111  10.0  1.0  1.0  0.0  0.0
# 11112  11.0  1.0  4.0  0.0  0.0

# %%
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#         Season              DateTime     HomeTeam        AwayTeam  FTHG  FTAG
# 0      1993-94  1993-08-14T00:00:00Z      Arsenal        Coventry     0     3  \
# 1      1993-94  1993-08-14T00:00:00Z  Aston Villa             QPR     4     1
# 2      1993-94  1993-08-14T00:00:00Z      Chelsea       Blackburn     1     2
# 3      1993-94  1993-08-14T00:00:00Z    Liverpool  Sheffield Weds     2     0
# 4      1993-94  1993-08-14T00:00:00Z     Man City           Leeds     1     1
# ...        ...                   ...          ...             ...   ...   ...
# 11108  2021-22  2022-04-09T17:30:00Z  Aston Villa       Tottenham     0     4
# 11109  2021-22  2022-04-10T14:00:00Z    Brentford        West Ham     2     0
# 11110  2021-22  2022-04-10T14:00:00Z    Leicester  Crystal Palace     2     1
# 11111  2021-22  2022-04-10T14:00:00Z      Norwich         Burnley     2     0
# 11112  2021-22  2022-04-10T16:30:00Z     Man City       Liverpool     2     2
#
#       FTR  HTHG  HTAG  HTR     Referee    HS    AS  HST  AST   HC   AC    HF
# 0       A   NaN   NaN  NaN         NaN   NaN   NaN  NaN  NaN  NaN  NaN   NaN  \
# 1       H   NaN   NaN  NaN         NaN   NaN   NaN  NaN  NaN  NaN  NaN   NaN
# 2       A   NaN   NaN  NaN         NaN   NaN   NaN  NaN  NaN  NaN  NaN   NaN
# 3       H   NaN   NaN  NaN         NaN   NaN   NaN  NaN  NaN  NaN  NaN   NaN
# 4       D   NaN   NaN  NaN         NaN   NaN   NaN  NaN  NaN  NaN  NaN   NaN
# ...    ..   ...   ...  ...         ...   ...   ...  ...  ...  ...  ...   ...
# 11108   A   0.0   1.0    A     G Scott   9.0  11.0  8.0  5.0  9.0  3.0  12.0
# 11109   H   0.0   0.0    D  M Atkinson  15.0   5.0  7.0  1.0  4.0  6.0   2.0
# 11110   H   2.0   0.0    H     R Jones  12.0  11.0  3.0  3.0  3.0  4.0  11.0
# 11111   H   1.0   0.0    H    M Oliver  17.0  18.0  6.0  4.0  6.0  7.0  12.0
# 11112   D   2.0   1.0    H    A Taylor  11.0   6.0  5.0  4.0  4.0  1.0   9.0
#
#          AF   HY   AY   HR   AR
# 0       NaN  NaN  NaN  NaN  NaN
# 1       NaN  NaN  NaN  NaN  NaN
# 2       NaN  NaN  NaN  NaN  NaN
# 3       NaN  NaN  NaN  NaN  NaN
# 4       NaN  NaN  NaN  NaN  NaN
# ...     ...  ...  ...  ...  ...
# 11108  14.0  2.0  3.0  0.0  0.0
# 11109   6.0  0.0  1.0  0.0  0.0
# 11110  12.0  1.0  1.0  0.0  0.0
# 11111  10.0  1.0  1.0  0.0  0.0
# 11112  11.0  1.0  4.0  0.0  0.0
#
# [11113 rows x 23 columns]

# %%
df["HomeTeam"].value_counts()
df["AwayTeam"].value_counts()
# Out:
# AwayTeam
# Tottenham           552
# Chelsea             552
# Liverpool           552
# Everton             551
# Man United          551
# Arsenal             550
# Newcastle           514
# Aston Villa         495
# West Ham            495
# Man City            457
# Southampton         418
# Blackburn           327
# Sunderland          304
# Leicester           301
# Fulham              285
# Middlesbrough       266
# Leeds               248
# Bolton              247
# West Brom           247
# Crystal Palace      226
# Stoke               190
# Norwich             171
# Coventry            156
# Charlton            152
# Wigan               152
# Wolves              149
# Watford             149
# Burnley             148
# Sheffield Weds      137
# Wimbledon           137
# Derby               133
# Swansea             133
# Birmingham          133
# Portsmouth          133
# QPR                 118
# Bournemouth          95
# Hull                 95
# Brighton             91
# Ipswich              80
# Nott'm Forest        78
# Sheffield United     78
# Reading              57
# Bradford             38
# Cardiff              38
# Huddersfield         38
# Oldham               21
# Swindon              21
# Blackpool            19
# Barnsley             19
# Brentford            16
# Name: count, dtype: int64

# %%
df = df[df['Season'] != "2021-22"]

# %%
team_sum = df["AwayTeam"].value_counts() + df["HomeTeam"].value_counts()

# %%
team_sum.sort_values(ascending=False).tail()
# Out:
# Bradford     76
# Oldham       42
# Swindon      42
# Barnsley     38
# Blackpool    38
# Name: count, dtype: int64

# %%
team_sum.count()
# Out:
# 49

# %%
df.head()
# Out:
#     Season              DateTime     HomeTeam        AwayTeam  FTHG  FTAG FTR
# 0  1993-94  1993-08-14T00:00:00Z      Arsenal        Coventry     0     3   A  \
# 1  1993-94  1993-08-14T00:00:00Z  Aston Villa             QPR     4     1   H
# 2  1993-94  1993-08-14T00:00:00Z      Chelsea       Blackburn     1     2   A
# 3  1993-94  1993-08-14T00:00:00Z    Liverpool  Sheffield Weds     2     0   H
# 4  1993-94  1993-08-14T00:00:00Z     Man City           Leeds     1     1   D
#
#    HTHG  HTAG  HTR Referee  HS  AS  HST  AST  HC  AC  HF  AF  HY  AY  HR  AR
# 0   NaN   NaN  NaN     NaN NaN NaN  NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 1   NaN   NaN  NaN     NaN NaN NaN  NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 2   NaN   NaN  NaN     NaN NaN NaN  NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 3   NaN   NaN  NaN     NaN NaN NaN  NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 4   NaN   NaN  NaN     NaN NaN NaN  NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN

# %%
df.loc[1][2] #rows and columns
# Out:
# 'Aston Villa'

# %%
df.iloc[7500]
# Out:
# Season                   2012-13
# DateTime    2012-11-17T00:00:00Z
# HomeTeam               West Brom
# AwayTeam                 Chelsea
# FTHG                           2
# FTAG                           1
# FTR                            H
# HTHG                         1.0
# HTAG                         1.0
# HTR                            D
# Referee                 M Oliver
# HS                           8.0
# AS                          19.0
# HST                          6.0
# AST                         12.0
# HC                           0.0
# AC                          12.0
# HF                           7.0
# AF                          13.0
# HY                           0.0
# AY                           0.0
# HR                           0.0
# AR                           0.0
# Name: 7500, dtype: object

# %%
df["FTAG"].mean()
# Out:
# 1.1368011847463901

# %%
df["FTHG"].mean()
# Out:
# 1.5191595705294336

# %%
df["FTHG"].sum() + df["FTAG"].sum()
# Out:
# 28695

# %%
df["HomeTeam"].unique()
# Out:
# array(['Arsenal', 'Aston Villa', 'Chelsea', 'Liverpool', 'Man City',
#        'Newcastle', 'Oldham', 'Sheffield United', 'Southampton',
#        'West Ham', 'Norwich', 'Tottenham', 'Everton', 'Ipswich', 'Leeds',
#        'Wimbledon', 'Blackburn', 'Coventry', 'Man United', 'QPR',
#        'Sheffield Weds', 'Swindon', 'Crystal Palace', 'Leicester',
#        "Nott'm Forest", 'Bolton', 'Middlesbrough', 'Derby', 'Sunderland',
#        'Barnsley', 'Charlton', 'Watford', 'Bradford', 'Fulham',
#        'Birmingham', 'West Brom', 'Portsmouth', 'Wolves', 'Wigan',
#        'Reading', 'Hull', 'Stoke', 'Burnley', 'Blackpool', 'Swansea',
#        'Cardiff', 'Bournemouth', 'Brighton', 'Huddersfield'], dtype=object)

# %%
len(df)
# Out:
# 10804

# %%
#Attemp to count the number of wins

# %%
df.iloc[1] #go through every game
# Out:
# Season                   1993-94
# DateTime    1993-08-14T00:00:00Z
# HomeTeam             Aston Villa
# AwayTeam                     QPR
# FTHG                           4
# FTAG                           1
# FTR                            H
# HTHG                         NaN
# HTAG                         NaN
# HTR                          NaN
# Referee                      NaN
# HS                           NaN
# AS                           NaN
# HST                          NaN
# AST                          NaN
# HC                           NaN
# AC                           NaN
# HF                           NaN
# AF                           NaN
# HY                           NaN
# AY                           NaN
# HR                           NaN
# AR                           NaN
# Name: 1, dtype: object

# %%
df.iloc[1][2] #Access the home team
# Out:
# 'Aston Villa'

# %%
df.iloc[1]
# Out:
# Season                   1993-94
# DateTime    1993-08-14T00:00:00Z
# HomeTeam             Aston Villa
# AwayTeam                     QPR
# FTHG                           4
# FTAG                           1
# FTR                            H
# HTHG                         NaN
# HTAG                         NaN
# HTR                          NaN
# Referee                      NaN
# HS                           NaN
# AS                           NaN
# HST                          NaN
# AST                          NaN
# HC                           NaN
# AC                           NaN
# HF                           NaN
# AF                           NaN
# HY                           NaN
# AY                           NaN
# HR                           NaN
# AR                           NaN
# Name: 1, dtype: object

# %%
team_sum
# Out:
# Arsenal             1072
# Aston Villa          958
# Barnsley              38
# Birmingham           266
# Blackburn            654
# Blackpool             38
# Bolton               494
# Bournemouth          190
# Bradford              76
# Brighton             152
# Burnley              266
# Cardiff               76
# Charlton             304
# Chelsea             1072
# Coventry             312
# Crystal Palace       422
# Derby                266
# Everton             1072
# Fulham               570
# Huddersfield          76
# Hull                 190
# Ipswich              160
# Leeds                464
# Leicester            574
# Liverpool           1072
# Man City             882
# Man United          1072
# Middlesbrough        532
# Newcastle            996
# Norwich              312
# Nott'm Forest        156
# Oldham                42
# Portsmouth           266
# QPR                  236
# Reading              114
# Sheffield United     156
# Sheffield Weds       274
# Southampton          806
# Stoke                380
# Sunderland           608
# Swansea              266
# Swindon               42
# Tottenham           1072
# Watford              266
# West Brom            494
# West Ham             958
# Wigan                304
# Wimbledon            274
# Wolves               266
# Name: count, dtype: int64

# %%
df.iloc[1]
# Out:
# Season                   1993-94
# DateTime    1993-08-14T00:00:00Z
# HomeTeam             Aston Villa
# AwayTeam                     QPR
# FTHG                           4
# FTAG                           1
# FTR                            H
# HTHG                         NaN
# HTAG                         NaN
# HTR                          NaN
# Referee                      NaN
# HS                           NaN
# AS                           NaN
# HST                          NaN
# AST                          NaN
# HC                           NaN
# AC                           NaN
# HF                           NaN
# AF                           NaN
# HY                           NaN
# AY                           NaN
# HR                           NaN
# AR                           NaN
# Name: 1, dtype: object

# %%
team_sum.sort_index()
# Out:
# Arsenal             1072
# Aston Villa          958
# Barnsley              38
# Birmingham           266
# Blackburn            654
# Blackpool             38
# Bolton               494
# Bournemouth          190
# Bradford              76
# Brighton             152
# Burnley              266
# Cardiff               76
# Charlton             304
# Chelsea             1072
# Coventry             312
# Crystal Palace       422
# Derby                266
# Everton             1072
# Fulham               570
# Huddersfield          76
# Hull                 190
# Ipswich              160
# Leeds                464
# Leicester            574
# Liverpool           1072
# Man City             882
# Man United          1072
# Middlesbrough        532
# Newcastle            996
# Norwich              312
# Nott'm Forest        156
# Oldham                42
# Portsmouth           266
# QPR                  236
# Reading              114
# Sheffield United     156
# Sheffield Weds       274
# Southampton          806
# Stoke                380
# Sunderland           608
# Swansea              266
# Swindon               42
# Tottenham           1072
# Watford              266
# West Brom            494
# West Ham             958
# Wigan                304
# Wimbledon            274
# Wolves               266
# Name: count, dtype: int64

# %%
type(team_sum)
# Out:
# pandas.core.series.Series

# %%
team_sum = team_sum.to_frame()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17780\3882813569.py in ?()
# ----> 1 team_sum = team_sum.to_frame()
#
# c:\Users\AlexanderTkachenko\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'to_frame'

# %%
type(team_sum)
# Out:
# pandas.core.frame.DataFrame

# %%
team_sum["Win"] = 0

# %%
team_sum["Draw"] = 0

# %%
team_sum["Loss"] = 0

# %%
team_sum
# Out:
#                    count  Win  Draw  Loss
# Arsenal           1072.0    0     0     0
# Aston Villa        958.0    0     0     0
# Barnsley            38.0    0     0     0
# Birmingham         266.0    0     0     0
# Blackburn          654.0    0     0     0
# Blackpool           38.0    0     0     0
# Bolton             494.0    0     0     0
# Bournemouth        190.0    0     0     0
# Bradford            76.0    0     0     0
# Brighton           152.0    0     0     0
# Burnley            266.0    0     0     0
# Cardiff             76.0    0     0     0
# Charlton           304.0    0     0     0
# Chelsea           1072.0    0     0     0
# Coventry           312.0    0     0     0
# Crystal Palace     422.0    0     0     0
# Derby              266.0    0     0     0
# Everton           1072.0    0     0     0
# Fulham             570.0    0     0     0
# Huddersfield        76.0    0     0     0
# Hull               190.0    0     0     0
# Ipswich            160.0    0     0     0
# Leeds              464.0    0     0     0
# Leicester          574.0    0     0     0
# Liverpool         1072.0    0     0     0
# Man City           882.0    0     0     0
# Man United        1072.0    0     0     0
# Middlesbrough      532.0    0     0     0
# Newcastle          996.0    0     0     0
# Norwich            312.0    0     0     0
# Nott'm Forest      156.0    0     0     0
# Oldham              42.0    0     0     0
# Portsmouth         266.0    0     0     0
# QPR                236.0    0     0     0
# Reading            114.0    0     0     0
# Sheffield United   156.0    0     0     0
# Sheffield Weds     274.0    0     0     0
# Southampton        806.0    0     0     0
# Stoke              380.0    0     0     0
# Sunderland         608.0    0     0     0
# Swansea            266.0    0     0     0
# Swindon             42.0    0     0     0
# Tottenham         1072.0    0     0     0
# Watford            266.0    0     0     0
# West Brom          494.0    0     0     0
# West Ham           958.0    0     0     0
# Wigan              304.0    0     0     0
# Wimbledon          274.0    0     0     0
# Wolves             266.0    0     0     0
# Win                  0.0    0     0     0
# Draw                 0.0    0     0     0
# Loss                 0.0    0     0     0

# %%
team_sum.drop("Win", inplace=True)

# %%
team_sum.drop("Draw", inplace=True)

# %%
team_sum.drop("Loss", inplace=True)

# %%
team_sum
# Out:
#                    count  Win  Draw  Loss
# Arsenal           1072.0    0     0     0
# Aston Villa        958.0    0     0     0
# Barnsley            38.0    0     0     0
# Birmingham         266.0    0     0     0
# Blackburn          654.0    0     0     0
# Blackpool           38.0    0     0     0
# Bolton             494.0    0     0     0
# Bournemouth        190.0    0     0     0
# Bradford            76.0    0     0     0
# Brighton           152.0    0     0     0
# Burnley            266.0    0     0     0
# Cardiff             76.0    0     0     0
# Charlton           304.0    0     0     0
# Chelsea           1072.0    0     0     0
# Coventry           312.0    0     0     0
# Crystal Palace     422.0    0     0     0
# Derby              266.0    0     0     0
# Everton           1072.0    0     0     0
# Fulham             570.0    0     0     0
# Huddersfield        76.0    0     0     0
# Hull               190.0    0     0     0
# Ipswich            160.0    0     0     0
# Leeds              464.0    0     0     0
# Leicester          574.0    0     0     0
# Liverpool         1072.0    0     0     0
# Man City           882.0    0     0     0
# Man United        1072.0    0     0     0
# Middlesbrough      532.0    0     0     0
# Newcastle          996.0    0     0     0
# Norwich            312.0    0     0     0
# Nott'm Forest      156.0    0     0     0
# Oldham              42.0    0     0     0
# Portsmouth         266.0    0     0     0
# QPR                236.0    0     0     0
# Reading            114.0    0     0     0
# Sheffield United   156.0    0     0     0
# Sheffield Weds     274.0    0     0     0
# Southampton        806.0    0     0     0
# Stoke              380.0    0     0     0
# Sunderland         608.0    0     0     0
# Swansea            266.0    0     0     0
# Swindon             42.0    0     0     0
# Tottenham         1072.0    0     0     0
# Watford            266.0    0     0     0
# West Brom          494.0    0     0     0
# West Ham           958.0    0     0     0
# Wigan              304.0    0     0     0
# Wimbledon          274.0    0     0     0
# Wolves             266.0    0     0     0

# %%
df.iloc[1]
# Out:
# Season                   1993-94
# DateTime    1993-08-14T00:00:00Z
# HomeTeam             Aston Villa
# AwayTeam                     QPR
# FTHG                           4
# FTAG                           1
# FTR                            H
# HTHG                         NaN
# HTAG                         NaN
# HTR                          NaN
# Referee                      NaN
# HS                           NaN
# AS                           NaN
# HST                          NaN
# AST                          NaN
# HC                           NaN
# AC                           NaN
# HF                           NaN
# AF                           NaN
# HY                           NaN
# AY                           NaN
# HR                           NaN
# AR                           NaN
# Name: 1, dtype: object

# %%
team_sum["Liverpool"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\AlexanderTkachenko\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File c:\Users\AlexanderTkachenko\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\AlexanderTkachenko\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Liverpool'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 team_sum["Liverpool"]
#
# File c:\Users\AlexanderTkachenko\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File c:\Users\AlexanderTkachenko\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'Liverpool'

# %%
for i in range (len(df)):
    HT = df.iloc[2]
    AT = df.iloc[3]
    res = df.iloc[6]

    if res == "D":
        HT = team_sum[HT]
        AT = team_sum[AT]
        team_sum[HT] = team
